# %%
import cv2

# %%
import face_cluster

# %%
from glob import glob

imgs = [cv2.imread(url) for url in glob("/notebooks/TaufeAnna/*.jpg")]

# %%
(descriptors, bounding_boxes) = face_cluster.predict_images(imgs)

# %%
face_cluster.cluster(descriptors, 0.6)
# Out:
# [[0, 1, 0],
#  [],
#  [1, 0],
#  [],
#  [],
#  [],
#  [2, 3, 0, 1],
#  [],
#  [],
#  [],
#  [],
#  [4, 2, 5],
#  [0],
#  [],
#  [0, 4, 4, 6],
#  [0],
#  [],
#  [7, 4],
#  [3, 2, 3],
#  [],
#  [],
#  [0, 0],
#  [],
#  [3, 1, 0],
#  [0],
#  [4, 7, 1],
#  [0],
#  [5, 1],
#  [],
#  [0],
#  [3, 4, 4],
#  [2, 3, 0],
#  [0],
#  [0],
#  [],
#  [0, 1, 3],
#  [4, 2],
#  [1],
#  [0],
#  [5, 8, 0],
#  [7, 9, 4, 0, 0, 10],
#  [0],
#  [3, 4],
#  [0],
#  [],
#  [0, 0],
#  [10],
#  [],
#  [],
#  [],
#  [0],
#  [2, 0, 3, 3, 8, 1, 1, 6, 4],
#  [8, 2],
#  [7, 0],
#  [],
#  [5, 1, 0],
#  [2, 0],
#  [],
#  [0, 0, 4, 0],
#  [],
#  [],
#  [2, 3, 3],
#  [0],
#  [4, 1],
#  [0],
#  [],
#  [2, 1],
#  [],
#  [],
#  [1, 0, 0],
#  [],
#  [],
#  [],
#  [1, 4],
#  [7],
#  [3],
#  [],
#  [0, 0],
#  [0, 0],
#  [],
#  [5, 4],
#  [3, 3, 2, 1],
#  [6],
#  [2],
#  [2, 3, 1, 3],
#  [1],
#  [2, 0, 10, 3],
#  [],
#  [0, 1],
#  [3, 0],
#  [8],
#  [0, 0, 9, 1, 3, 10],
#  [2, 4, 3],
#  [],
#  [9, 2, 0],
#  [],
# ...
